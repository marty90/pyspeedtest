# %%
import json
import matplotlib.pyplot as plt
import fastplot
import pandas as pd
from glob import glob

# %%
data = []
for f in glob("test*/*/result.json"):
    j = json.load(open(f,"r"))
    data.append(j)
df = pd.DataFrame(data)    
df["download_mbps"] = df["download_mbps"].astype(float)
df["upload_mbps"] = df["upload_mbps"].astype(float)
df.head()
# Out:
#    browser  download_mbps  iteration  \
# 0   chrome         651.23         61
# 1  firefox         938.51         67
# 2   chrome         917.83         90
# 3   chrome         920.93         82
# 4   chrome         923.13        104
#
#                                         organization ping_ms      server_ip  \
# 0  Consorzio Top Ix - Torino E Piemonte Exchange ...       1  194.116.85.68
# 1  Consorzio Top Ix - Torino E Piemonte Exchange ...       1  194.116.85.68
# 2  Consorzio Top Ix - Torino E Piemonte Exchange ...       1  194.116.85.68
# 3  Consorzio Top Ix - Torino E Piemonte Exchange ...       1  194.116.85.68
# 4  Consorzio Top Ix - Torino E Piemonte Exchange ...       1  194.116.85.68
#
#            time  upload_mbps
# 0  1.569865e+09       854.86
# 1  1.569865e+09       857.44
# 2  1.569868e+09       857.79
# 3  1.569867e+09       862.61
# 4  1.569870e+09       861.50

# %%
grouped = df.groupby("browser")["download_mbps"].apply(list).reset_index().values
fastplot.plot(grouped, None, mode='CDF_multi', legend=True).show()

# %%
grouped = df.groupby("browser")["upload_mbps"].apply(list).reset_index().values
fastplot.plot(grouped, None, mode='CDF_multi', legend=True).show()
